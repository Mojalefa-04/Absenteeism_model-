# %%
link = "https://public.tableau.com/app/profile/mojalefa.progress.mokhathi/vizzes"

with open("/Users/promojz/Documents/Business_Problem_ML_Project/Tableau/Tableau_viz.text" , "w") as file :
    file.write(link)
