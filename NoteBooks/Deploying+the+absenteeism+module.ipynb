# %% [markdown]
# ## Deploying the absenteeism module

# %%
import sys

# add the module folder to python path
sys.path.append('/Users/promojz/Documents/Business_Problem_ML_Project/module')

# %%
from absenteeism_module import *

# %%
model = absenteeism_model('model','scaler')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 model0 = absenteeism_model('model.pkl','scaler.pkl')
#
# File ~/Documents/Business_Problem_ML_Project/module/absenteeism_module.py:41, in absenteeism_model.__init__(self, model_file, scaler_file)
#      39 def __init__(self, model_file, scaler_file):
#      40     # read the 'model' and 'scaler' files which were saved
# ---> 41     with open('model','rb') as model_file, open('scaler', 'rb') as scaler_file:
#      42         self.reg = pickle.load(model_file)
#      43         self.scaler = pickle.load(scaler_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model'

# %%
df = model.predicted_outputs()
df['Reason_1'] = df['Reason_1'].astype(int)
df['Reason_2'] = df['Reason_2'].astype(int)
df['Reason_3'] = df['Reason_3'].astype(int)
df['Reason_4'] = df['Reason_4'].astype(int)
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df = model.predicted_outputs()
#       2 df['Reason_1'] = df['Reason_1'].astype(int)
#       3 df['Reason_2'] = df['Reason_2'].astype(int)
#
# NameError: name 'model' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Saving the data with probabilities & predictions

# %%
df.to_csv('Absenteeism_predictions.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.to_csv('Absenteeism_predictions.csv', index = False)
#
# NameError: name 'df' is not defined
